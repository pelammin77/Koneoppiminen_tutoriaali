# %%
"""
File: mean_Shift_iris.IPYNB
Author: Petri Lamminaho 
Description: Simple Iris dataset Clustering with Sklearn MeanShift algorithm 
"""
from sklearn import datasets
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import MeanShift

# %%
iris = datasets.load_iris()
X = iris.data[:, :2]
y = iris.target

# %%
plt.scatter(X[:,0], X[:,1], c=y, cmap='gist_rainbow')
plt.xlabel('Spea1 Length', fontsize=20)
plt.ylabel('Sepal Width', fontsize=20)
# Out:
# Text(0,0.5,'Sepal Width')

# %%
MS_model  = MeanShift()
MS_model.fit(X)
# Out:
# MeanShift(bandwidth=None, bin_seeding=False, cluster_all=True, min_bin_freq=1,
#      n_jobs=1, seeds=None)

# %%
center_points = MS_model.cluster_centers_
center_points
# Out:
# array([[6.22      , 2.892     ],
#        [5.41142857, 3.02571429]])

# %%
new_labels = MS_model.labels_

# Plot the identified clusters and compare with the answers

fig, axes = plt.subplots(1, 2, figsize=(16,8))

axes[0].scatter(X[:, 0], X[:, 1], c=y, cmap='gist_rainbow',

edgecolor='k', s=150)

axes[1].scatter(X[:, 0], X[:, 1], c=new_labels, cmap='jet',

edgecolor='k', s=150)

axes[0].set_xlabel('Sepal length', fontsize=18)

axes[0].set_ylabel('Sepal width', fontsize=18)

axes[1].set_xlabel('Sepal length', fontsize=18)

axes[1].set_ylabel('Sepal width', fontsize=18)

axes[0].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)

axes[1].tick_params(direction='in', length=10, width=5, colors='k', labelsize=20)

axes[0].set_title('True value', fontsize=18)

axes[1].set_title('Model pred', fontsize=18)
# Out:
# Text(0.5,1,'Model pred')
